# %%
pip install colormap
# Out:
# Collecting colormap
#   Downloading colormap-1.0.6.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from colormap) (3.7.1)
# Collecting easydev (from colormap)
#   Downloading easydev-0.13.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 1.1 MB/s eta 0:00:00
# Collecting colorama<0.5.0,>=0.4.6 (from easydev->colormap)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting colorlog<7.0.0,>=6.8.2 (from easydev->colormap)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Collecting line-profiler<5.0.0,>=4.1.2 (from easydev->colormap)
#   Downloading line_profiler-4.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (714 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 714.8/714.8 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: pexpect<5.0.0,>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from easydev->colormap) (4.9.0)
# Requirement already satisfied: platformdirs<5.0.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from easydev->colormap) (4.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->colormap) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->colormap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->colormap) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->colormap) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->colormap) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->colormap) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->colormap) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->colormap) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->colormap) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect<5.0.0,>=4.9.0->easydev->colormap) (0.7.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->colormap) (1.16.0)
# Building wheels for collected packages: colormap
#   Building wheel for colormap (setup.py) ... done
#   Created wheel for colormap: filename=colormap-1.0.6-py3-none-any.whl size=15824 sha256=ec5a688e38ca6124252c1402e5feca8495657b89fbdb210155cb4014ba049814
#   Stored in directory: /root/.cache/pip/wheels/ea/c2/2c/8799f753a6c0acef2a86a40c7c091fa70d0f49785f1f28fba1
# Successfully built colormap
# Installing collected packages: line-profiler, colorlog, colorama, easydev, colormap
# Successfully installed colorama-0.4.6 colorlog-6.8.2 colormap-1.0.6 easydev-0.13.1 line-profiler-4.1.2

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import datasets
from sklearn.neighbors import KNeighborsClassifier

# %%
iris = datasets.load_iris()

X = iris.data[:, :2]
y = iris.target

# %%
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# %%
clf1 = KNeighborsClassifier(n_neighbors=1)
clf1.fit(X, y)

clf5 = KNeighborsClassifier(n_neighbors=5)
clf5.fit(X, y)
# Out:
# KNeighborsClassifier()

# %%
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                     np.arange(y_min, y_max, 0.02))

# %%
Z1 = clf1.predict(np.c_[xx.ravel(), yy.ravel()])
Z1 = Z1.reshape(xx.shape)

Z5 = clf5.predict(np.c_[xx.ravel(), yy.ravel()])
Z5 = Z5.reshape(xx.shape)

# %%
plt.figure(figsize=(12, 6))

# %%
plt.subplot(1, 2, 1)
plt.pcolormesh(xx, yy, Z1, cmap=cmap_light)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, edgecolor='k', s=20)
plt.title("k-NN decision boundary (k=1)")
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
# Out:
# Text(0, 0.5, 'Sepal width')

# %%
plt.subplot(1, 2, 2)
plt.pcolormesh(xx, yy, Z5, cmap=cmap_light)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, edgecolor='k', s=20)
plt.title("k-NN decision boundary (k=5)")
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
# Out:
# Text(0, 0.5, 'Sepal width')

# %%
plt.tight_layout()
plt.show()
